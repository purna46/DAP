# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

sentences = ['I love learning','I love python','I hate school',
             'Recurrent Neural Networks are powerful']

tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

input_sequences = []
for sentence in sentences:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)

max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X, y, epochs=50, verbose=2)

seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Epoch 1/50
# 1/1 - 1s - loss: 2.4544 - accuracy: 0.2000 - 1s/epoch - 1s/step
# Epoch 2/50
# 1/1 - 0s - loss: 2.3721 - accuracy: 0.2000 - 7ms/epoch - 7ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 2.2920 - accuracy: 0.2000 - 7ms/epoch - 7ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 2.2139 - accuracy: 0.3000 - 7ms/epoch - 7ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 2.1387 - accuracy: 0.3000 - 7ms/epoch - 7ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 2.0677 - accuracy: 0.3000 - 8ms/epoch - 8ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 2.0003 - accuracy: 0.3000 - 8ms/epoch - 8ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 1.9330 - accuracy: 0.3000 - 6ms/epoch - 6ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 1.8624 - accuracy: 0.3000 - 6ms/epoch - 6ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 1.7879 - accuracy: 0.4000 - 6ms/epoch - 6ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 1.7120 - accuracy: 0.4000 - 8ms/epoch - 8ms/step
# Epoch 12/50
# 1/1 - 0s - loss: 1.6371 - accuracy: 0.6000 - 10ms/epoch - 10ms/step
# Epoch 13/50
# 1/1 - 0s - loss: 1.5641 - accuracy: 0.6000 - 7ms/epoch - 7ms/step
# Epoch 14/50
# 1/1 - 0s - loss: 1.4931 - accuracy: 0.7000 - 7ms/epoch - 7ms/step
# Epoch 15/50
# 1/1 - 0s - loss: 1.4251 - accuracy: 0.7000 - 7ms/epoch - 7ms/step
# Epoch 16/50
# 1/1 - 0s - loss: 1.3610 - accuracy: 0.7000 - 8ms/epoch - 8ms/step
# Epoch 17/50
# 1/1 - 0s - loss: 1.3016 - accuracy: 0.7000 - 8ms/epoch - 8ms/step
# Epoch 18/50
# 1/1 - 0s - loss: 1.2471 - accuracy: 0.7000 - 8ms/epoch - 8ms/step
# Epoch 19/50
# 1/1 - 0s - loss: 1.1965 - accuracy: 0.7000 - 7ms/epoch - 7ms/step
# Epoch 20/50
# 1/1 - 0s - loss: 1.1489 - accuracy: 0.7000 - 7ms/epoch - 7ms/step
# Epoch 21/50
# 1/1 - 0s - loss: 1.1038 - accuracy: 0.7000 - 8ms/epoch - 8ms/step
# Epoch 22/50
# 1/1 - 0s - loss: 1.0617 - accuracy: 0.7000 - 8ms/epoch - 8ms/step
# Epoch 23/50
# 1/1 - 0s - loss: 1.0213 - accuracy: 0.7000 - 11ms/epoch - 11ms/step
# Epoch 24/50
# 1/1 - 0s - loss: 0.9811 - accuracy: 0.7000 - 8ms/epoch - 8ms/step
# Epoch 25/50
# 1/1 - 0s - loss: 0.9405 - accuracy: 0.7000 - 7ms/epoch - 7ms/step
# Epoch 26/50
# 1/1 - 0s - loss: 0.9006 - accuracy: 0.7000 - 6ms/epoch - 6ms/step
# Epoch 27/50
# 1/1 - 0s - loss: 0.8626 - accuracy: 0.7000 - 6ms/epoch - 6ms/step
# Epoch 28/50
# 1/1 - 0s - loss: 0.8267 - accuracy: 0.7000 - 6ms/epoch - 6ms/step
# Epoch 29/50
# 1/1 - 0s - loss: 0.7923 - accuracy: 0.7000 - 6ms/epoch - 6ms/step
# Epoch 30/50
# 1/1 - 0s - loss: 0.7597 - accuracy: 0.7000 - 6ms/epoch - 6ms/step
# Epoch 31/50
# 1/1 - 0s - loss: 0.7294 - accuracy: 0.7000 - 8ms/epoch - 8ms/step
# Epoch 32/50
# 1/1 - 0s - loss: 0.7016 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 33/50
# 1/1 - 0s - loss: 0.6758 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 34/50
# 1/1 - 0s - loss: 0.6518 - accuracy: 0.8000 - 9ms/epoch - 9ms/step
# Epoch 35/50
# 1/1 - 0s - loss: 0.6296 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 36/50
# 1/1 - 0s - loss: 0.6088 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 37/50
# 1/1 - 0s - loss: 0.5891 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 38/50
# 1/1 - 0s - loss: 0.5704 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 39/50
# 1/1 - 0s - loss: 0.5531 - accuracy: 0.8000 - 8ms/epoch - 8ms/step
# Epoch 40/50
# 1/1 - 0s - loss: 0.5370 - accuracy: 0.8000 - 12ms/epoch - 12ms/step
# Epoch 41/50
# 1/1 - 0s - loss: 0.5216 - accuracy: 0.8000 - 10ms/epoch - 10ms/step
# Epoch 42/50
# 1/1 - 0s - loss: 0.5067 - accuracy: 0.8000 - 8ms/epoch - 8ms/step
# Epoch 43/50
# 1/1 - 0s - loss: 0.4927 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 44/50
# 1/1 - 0s - loss: 0.4797 - accuracy: 0.8000 - 6ms/epoch - 6ms/step
# Epoch 45/50
# 1/1 - 0s - loss: 0.4673 - accuracy: 0.8000 - 9ms/epoch - 9ms/step
# Epoch 46/50
# 1/1 - 0s - loss: 0.4554 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 47/50
# 1/1 - 0s - loss: 0.4443 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 48/50
# 1/1 - 0s - loss: 0.4339 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Epoch 49/50
# 1/1 - 0s - loss: 0.4244 - accuracy: 0.8000 - 8ms/epoch - 8ms/step
# Epoch 50/50
# 1/1 - 0s - loss: 0.4156 - accuracy: 0.8000 - 7ms/epoch - 7ms/step
# Enter the starting word: i love
# Enter how many words to predict: 5
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# i love python neural school are powerful
